# %% [markdown]
# # How to read text from an image using Pytesseract

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# ## Reading the images

# %%
import cv2
from PIL import Image

img1 = cv2.imread('image1.png')
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=283x178>

# %%
img2 = cv2.imread('image2.jpg')
Image.fromarray(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=318x159>

# %%
img3 = cv2.imread('image3.jpg')
Image.fromarray(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=302x167>

# %% [markdown]
# ## Reading the text from the image

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text = pytesseract.image_to_string(img1 , lang='eng')
print(text)
# Out:
# It was the best of
# times, it was the worst
# of times, it was the age
# of wisdom, it was the
# age of foolishness...

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text = pytesseract.image_to_string(img2 , lang='eng')
print(text)
# Out:
# JUICE

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text = pytesseract.image_to_string(img3 , lang='eng')
print(text)
# Out:
# FTAA PAI AE ARENT Hen TARE TTI
# serpamdicdhioryplladderrenvaparau iliac
# ‘hlyperensiongrandyyotyrsonmedeioesvarsbutolalopaina
# tapicobetallexcoumalevonlsinnyeetoninoneorelelaieily
# ceinisrstestsernnvespmialergesnoxrnmirialessecastntipst
# *Hinesnoveisopeundandsinehesallenbisanmetieorrsanear more
# tient niteaeneptveorieartdonesighlecerandhyprenanaed
# neaintonlontereensltensteptenisentetrhypeensanee nt
# heindsoreiespnhvangaenaprmimnactonnesn rena
# Ccrdabwestnrtdaeseanmantrcinecsnsannonaptrltet pre
# serleerthoralnterersevlaynannerereiewehepsesandaenls
# Sedacheneuonupeeatthstaryunrsonarepsnepaetacepeatjetpt
# Uasvetdetyaoltbepatidoemetavenymtoaloneratedoes
